# %% [markdown]
# # Function for data download and processing

# %%
import pandas as pd
import pickle
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

pd.set_option('max_columns', 100)

def prepare_sparse_features(path_to_train, path_to_test, path_to_site_dict,
                           vectorizer_params):
    times = ['time%s' % i for i in range(1, 11)]
    train_df = pd.read_csv(path_to_train,
                       index_col='session_id', parse_dates=times)
    test_df = pd.read_csv(path_to_test,
                      index_col='session_id', parse_dates=times)

    # Sort the data by time
    train_df = train_df.sort_values(by='time1')
    
    # read site -> id mapping provided by competition organizers 
    with open(path_to_site_dict, 'rb') as f:
        site2id = pickle.load(f)
    # create an inverse id _> site mapping
    id2site = {v:k for (k, v) in site2id.items()}
    # we treat site with id 0 as "unknown"
    id2site[0] = 'unknown'
    
    # Transform data into format which can be fed into TfidfVectorizer
    # This time we prefer to represent sessions with site names, not site ids. 
    # It's less efficient but thus it'll be more convenient to interpret model weights.
    sites = ['site%s' % i for i in range(1, 11)]
    train_sessions = train_df[sites].fillna(0).astype('int').apply(lambda row: 
                                                     ' '.join([id2site[i] for i in row]), axis=1).tolist()
    test_sessions = test_df[sites].fillna(0).astype('int').apply(lambda row: 
                                                     ' '.join([id2site[i] for i in row]), axis=1).tolist()
    # we'll tell TfidfVectorizer that we'd like to split data by whitespaces only 
    # so that it doesn't split by dots (we wouldn't like to have 'mail.google.com' 
    # to be split into 'mail', 'google' and 'com')
    vectorizer = TfidfVectorizer(**vectorizer_params)
    X_train = vectorizer.fit_transform(train_sessions)
    X_test = vectorizer.transform(test_sessions)
    y_train = train_df['target'].astype('int').values
    
    # we'll need site visit times for further feature engineering
    train_times, test_times = train_df[times], test_df[times]
    
    return X_train, X_test, y_train, vectorizer, train_times, test_times

# %% [markdown]
# # Download and process data

# %%
# %%time
import os

PATH_TO_DATA = ''
SEED = 88

X_train_sites, X_test_sites, y_train, vectorizer, train_times, test_times = prepare_sparse_features(
    path_to_train=os.path.join(PATH_TO_DATA, 'train_sessions.csv'),
    path_to_test=os.path.join(PATH_TO_DATA, 'test_sessions.csv'),
    path_to_site_dict=os.path.join(PATH_TO_DATA, 'site_dic.pkl'),
    vectorizer_params={'ngram_range': (1, 5), 
                       'max_features': 50000,
                       'tokenizer': lambda s: s.split()}
)
# Out:
# Wall time: 55.8 s

# %% [markdown]
# # Train a Logistic Regression model

# %%
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.linear_model import LogisticRegression

tss = TimeSeriesSplit(n_splits=10)
lr = LogisticRegression(C=1, random_state=SEED, solver='liblinear')
cv1 = cross_val_score(lr, X_train_sites, y_train, cv=tss, n_jobs=7, scoring='roc_auc')
np.mean(cv1), np.std(cv1)
# Out:
# (0.8625366936681628, 0.07455710081058183)

# %% [markdown]
# # Fit the model

# %%
lr.fit(X_train_sites, y_train)
# Out:
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=88, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# # Display model weights with eli5

# %%
import eli5

eli5.show_weights(estimator=lr, 
                  feature_names=vectorizer.get_feature_names(), top=30)
# Out:
# d:\downloads\python\python37\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# d:\downloads\python\python37\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.880
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.380
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.222
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.86%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.114
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.875
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.499
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.220
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.147
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.089
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.003
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.993
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.945
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.95%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.917
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         reviewer.lavoixdunord.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.893
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.783
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r3---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.711
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.686
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.596
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         i1.ytimg.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.593
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.536
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.video.tt
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.521
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.purepeople.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.512
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %% [markdown]
# # Functions for automatization of model test and writing submission to file

# %%
from IPython.display import display_html

def write_to_submission_file(predicted_labels, out_file, target='target', index_label="session_id"):
    predicted_df = pd.DataFrame(predicted_labels,
                                index = np.arange(1, predicted_labels.shape[0] + 1),
                                columns=[target])
    predicted_df.to_csv(out_file, index_label=index_label)


def train_and_predict(model, X_train, y_train, X_test, site_feature_names=vectorizer.get_feature_names(), 
                      new_feature_names=None, cv=tss, scoring='roc_auc',
                      top_n_features_to_show=30, submission_file_name='submission.csv'):
    
    
    cv_scores = cross_val_score(model, X_train, y_train, cv=cv, 
                            scoring=scoring, n_jobs=4)
    print('CV scores', cv_scores)
    print('CV mean: {}, CV std: {}'.format(cv_scores.mean(), cv_scores.std()))
    model.fit(X_train, y_train)
    
    if new_feature_names:
        all_feature_names = site_feature_names + new_feature_names 
    else: 
        all_feature_names = site_feature_names
    
    display_html(eli5.show_weights(estimator=model, 
                  feature_names=all_feature_names, top=top_n_features_to_show))
    
    if new_feature_names:
        print('New feature weights:')
    
        print(pd.DataFrame({'feature': new_feature_names, 
                        'coef': model.coef_.flatten()[-len(new_feature_names):]}))
    
    test_pred = model.predict_proba(X_test)[:, 1]
    write_to_submission_file(test_pred, submission_file_name) 
    
    return cv_scores

cv_scores1 = train_and_predict(model=lr, X_train=X_train_sites, y_train=y_train, 
                               X_test=X_test_sites, site_feature_names=vectorizer.get_feature_names(),              
                               cv=tss, submission_file_name='subm1.csv')
# Out:
# CV scores [0.83124023 0.65993466 0.85673565 0.92824237 0.84779639 0.88954524
#  0.88829128 0.8771044  0.92023545 0.92624125]
# CV mean: 0.8625366936681628, CV std: 0.07455710081058183
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.880
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.380
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.222
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.86%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.114
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.875
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.499
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.220
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.147
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.089
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.003
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.993
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.945
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.95%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.917
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         reviewer.lavoixdunord.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.893
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.783
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r3---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.711
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.686
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.596
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         i1.ytimg.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.593
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.536
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.video.tt
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.521
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.purepeople.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.512
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %% [markdown]
# We have got a 0.90744 score on Kaggle. Let's impove it by adding time features.
#
# # Add new features
#
# * hour of session start
# * part of day: morning, noon, evening, night
# * number of visited sites (not unique) in session
# * length of session in seconds
# * average time of site visit in seconds
#
# # Add date and hour of session start

# %%
from sklearn.preprocessing import scale

train_times['start_hour'] = train_times['time1'].dt.hour.astype(int)
train_times['start_hour'] = pd.Categorical(train_times['start_hour'])
test_times['start_hour'] = test_times['time1'].dt.hour.astype(int)
test_times['start_hour'] = pd.Categorical(test_times['start_hour'])

# %% [markdown]
# # Determine last visit time for each session

# %%
null_time = pd.to_datetime(0)
times = ['time%s' % i for i in range(1, 11)]

def determine_last_visit_time(row):
    last_visit = null_time
    for value in row:
        if pd.isnull(value):
            return last_visit
        else:
            last_visit = value
    return last_visit

train_times['last_visit'] = train_times[times].apply(determine_last_visit_time, axis=1)
test_times['last_visit'] = test_times[times].apply(determine_last_visit_time, axis=1)

# %% [markdown]
# # Add part of day

# %%
def determine_part_of_day(hour):
    if hour >= 7 and hour <= 11:
        return 'morning'
    elif hour >= 12 and hour <= 18:
        return 'day'
    elif hour >= 18 and hour <= 23:
        return 'evening'
    else:
        return 'night'
    
train_times['part_of_day'] = train_times['start_hour'].apply(determine_part_of_day)
train_times['part_of_day'] = pd.Categorical(train_times['part_of_day'])
test_times['part_of_day'] = test_times['start_hour'].apply(determine_part_of_day)
train_times['part_of_day'] = pd.Categorical(train_times['part_of_day'])

# %% [markdown]
# # Add length of session in seconds

# %%
train_times['session_length'] = scale((train_times['last_visit'] - train_times['time1']).dt.total_seconds().astype(int))
test_times['session_length'] = scale((test_times['last_visit'] - test_times['time1']).dt.total_seconds().astype(int))

# %% [markdown]
# # Add num of visited sites

# %%
import numpy as np

train_times['num_of_sites'] = train_times[times].count(axis=1)
test_times['num_of_sites'] = test_times[times].count(axis=1)

# %% [markdown]
# # Add full session (10 sites visited) flag

# %%
train_times['full_session'] = train_times['num_of_sites'].apply(lambda x: 1 if x == 10 else 0)
test_times['full_session'] = test_times['num_of_sites'].apply(lambda x: 1 if x == 10 else 0)

# %% [markdown]
# # Add new feature columns to  train and test dataset

# %%
from scipy.sparse import hstack
from sklearn.preprocessing import scale

def add_new_features(df, features, cat_features=None):
    new_df = pd.DataFrame()
    if cat_features:
        new_df = pd.concat([new_df, pd.get_dummies(df[cat_features])], axis=1)
    new_df = pd.concat([new_df, df[features]], axis=1)
    return new_df

# %% [markdown]
# # Create new train and test datasets with additional features

# %%
new_train_features = add_new_features(train_times, ['full_session'], ['part_of_day'])
new_test_features = add_new_features(test_times, ['full_session'], ['part_of_day'])

X_train_sites_with_time = hstack([X_train_sites, new_train_features])
X_test_sites_with_time = hstack([X_test_sites, new_test_features])

X_train_sites_with_time.shape, X_test_sites_with_time.shape
# Out:
# ((253561, 50004), (82797, 50004))

# %% [markdown]
# # Train Logistic Regression model on new data

# %%
new_features = list(new_train_features.columns)

cv_scores2 = train_and_predict(model=lr, X_train=X_train_sites_with_time, y_train=y_train, 
                               X_test=X_test_sites_with_time, site_feature_names=vectorizer.get_feature_names(),              
                               new_feature_names=new_features, cv=tss, submission_file_name='subm2.csv')
# Out:
# CV scores [0.88092559 0.81436048 0.91873644 0.96166471 0.91532755 0.95238605
#  0.92869277 0.94027802 0.94693866 0.95285914]
# CV mean: 0.921216939381228, CV std: 0.04215698971785799
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.221
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.089
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.963
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.926
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.637
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.539
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.377
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.175
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.098
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.94%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.817
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.659
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.611
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.593
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.590
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.64%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.566
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         i1.ytimg.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.556
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.544
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.522
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         reviewer.lavoixdunord.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.483
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.450
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.379
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r3---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.348
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
# New feature weights:
#                feature      coef
# 0      part_of_day_day  0.409693
# 1  part_of_day_evening -2.804535
# 2  part_of_day_morning -3.326960
# 3         full_session  0.439722

# %%
cv_scores2 > cv_scores1
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %% [markdown]
# This model hits 0.94623 at public score. Let's add additional features like day of week, month and year
#
# # Add new time features

# %%
train_times['day_of_week'] = train_times['time1'].apply(lambda t: t.weekday()).astype(int)
test_times['day_of_week'] = test_times['time1'].apply(lambda t: t.weekday()).astype(int)

train_times['month'] = train_times['time1'].dt.month.astype(int)
test_times['month'] = test_times['time1'].dt.month.astype(int)

train_times['year'] = train_times['time1'].dt.year.astype(int)
test_times['year'] = test_times['time1'].dt.year.astype(int)

train_times['year_month'] = scale(train_times['time1'].dt.year.astype(int)*100 + \
train_times['time1'].dt.month.astype(int))
test_times['year_month'] = scale(test_times['time1'].dt.year.astype(int)*100 + \
test_times['time1'].dt.month.astype(int))

# %% [markdown]
# # Analyze day of week feature

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax1 = train_times[y_train==1]['day_of_week'].value_counts().sort_index().plot(kind='bar', ax=ax[0])
ax1.set_title('Activity by days of week for Alice')
ax2 = train_times[y_train==0]['day_of_week'].value_counts().sort_index().plot(kind='bar', ax=ax[1])
ax2.set_title('Activity by days of week for other users')
# Out:
# Text(0.5, 1.0, 'Activity by days of week for other users')

# %% [markdown]
# There is a significant difference in Alice acitivity in 3d day (Wensday). Let's use this feature.
#
# # Create new train and test datasets with additional features

# %%
new_train_features = add_new_features(train_times, ['full_session', 'year_month'], ['part_of_day'])
new_test_features = add_new_features(test_times, ['full_session', 'year_month'], ['part_of_day'])

X_train_sites_with_time = hstack([X_train_sites, new_train_features])
X_test_sites_with_time = hstack([X_test_sites, new_test_features])

X_train_sites_with_time.shape, X_test_sites_with_time.shape
# Out:
# ((253561, 50005), (82797, 50005))

# %% [markdown]
# # Train model with new features

# %%
new_features = list(new_train_features.columns)

cv_scores3 = train_and_predict(model=lr, X_train=X_train_sites_with_time, y_train=y_train, 
                               X_test=X_test_sites_with_time, site_feature_names=vectorizer.get_feature_names(),              
                               new_feature_names=new_features, cv=tss, submission_file_name='subm3.csv')
# Out:
# CV scores [0.88929626 0.81511693 0.949113   0.96738309 0.91913222 0.95221798
#  0.93806785 0.93811895 0.95120772 0.95390123]
# CV mean: 0.9273555223840221, CV std: 0.04279202704586593
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.138
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.947
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.837
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.821
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.71%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.546
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.431
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         tru.am
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.319
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.217
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.205
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.202
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.008
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.890
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.852
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.721
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.662
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.660
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.545
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         reviewer.lavoixdunord.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.437
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.clermont-filmfest.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.356
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.352
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.306
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.tete-en-lair.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.304
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mcetv.fr
#     </td>
#
# </tr
# New feature weights:
#                feature      coef
# 0      part_of_day_day  0.399463
# 1  part_of_day_evening -3.332982
# 2  part_of_day_morning -3.413973
# 3         full_session  0.640580
# 4           year_month -0.382520

# %% [markdown]
# We were able to improve our score to 0.94979
#
# Let's experiment with another features
#
# # Add day of week feature

# %%
new_train_features = add_new_features(train_times, ['full_session', 'year_month', 'day_of_week'],
                                      ['part_of_day'])
new_test_features = add_new_features(test_times, ['full_session', 'year_month', 'day_of_week'], 
                                     ['part_of_day'])

X_train_sites_with_time = hstack([X_train_sites, new_train_features])
X_test_sites_with_time = hstack([X_test_sites, new_test_features])
# Train model with new features
X_train_sites_with_time.shape, X_test_sites_with_time.shape
# Out:
# ((253561, 50006), (82797, 50006))

# %% [markdown]
# # Train model with new features

# %%
new_features = list(new_train_features.columns)

cv_scores4 = train_and_predict(model=lr, X_train=X_train_sites_with_time, y_train=y_train, 
                               X_test=X_test_sites_with_time, site_feature_names=vectorizer.get_feature_names(),              
                               new_feature_names=new_features, cv=tss, submission_file_name='subm4.csv')
# Out:
# CV scores [0.84057294 0.81434098 0.94524165 0.9638585  0.9160262  0.95927974
#  0.92560581 0.95280119 0.95634886 0.97014238]
# CV mean: 0.9244218241353901, CV std: 0.051321731071263775
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.86%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.133
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.039
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.983
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.893
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.717
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.444
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.78%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.414
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.397
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.94%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.993
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.812
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.48%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.802
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.781
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         i1.ytimg.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.708
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.629
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.547
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.23%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.542
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.527
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.479
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.423
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.290
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.demotivateur.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.289
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         reviewer.lavoixdunord.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.13%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.238
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r3---sn-gxo5
# New feature weights:
#                feature      coef
# 0      part_of_day_day  0.558950
# 1  part_of_day_evening -2.713368
# 2  part_of_day_morning -3.180708
# 3         full_session  0.537327
# 4           year_month -0.445007
# 5          day_of_week -0.380624

# %% [markdown]
# This feature gives us ROC_AUC public score 0.94530. Great! Now it's time to tune hyperparameters for our model.
#
# # Search for the best hyperparameters of model

# %%
from sklearn.model_selection import GridSearchCV

# here we've already narrowed down c_values to such a range.
# typically, you would start with a wider range of values to check
c_values = np.logspace(-2, 2, 20)
lr_grid_searcher = GridSearchCV(estimator=lr, param_grid={'C': c_values},
                                scoring='roc_auc', n_jobs=6, cv=tss, verbose=1)

lr_grid_searcher.fit(X_train_sites_with_time, y_train)
print((lr_grid_searcher.best_params_, lr_grid_searcher.best_score_))
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=6)]: Done 200 out of 200 | elapsed:  4.3min finished
# ({'C': 2.06913808111479}, 0.9260954096285241)

# %% [markdown]
# # Use optimized hyperparameters for model prediction

# %%
lr = LogisticRegression(C=2.069, random_state=SEED, solver='liblinear')

cv_scores5 = train_and_predict(model=lr, X_train=X_train_sites_with_time, y_train=y_train, 
                               X_test=X_test_sites_with_time, site_feature_names=vectorizer.get_feature_names(),              
                               new_feature_names=new_features, cv=tss, submission_file_name='subm5.csv')
# Out:
# CV scores [0.84710163 0.80529019 0.94808928 0.96789002 0.91966989 0.95861074
#  0.93393367 0.95029391 0.96053818 0.96952883]
# CV mean: 0.9260946340688175, CV std: 0.05280411347788796
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.607
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.814
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.443
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.393
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.354
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.348
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         tru.am
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.95%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.196
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.146
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.23%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.048
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.47%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.922
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.823
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.791
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.736
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.716
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.708
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.526
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.466
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.422
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.radio-canada.ca
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.376
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.clermont-filmfest.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.375
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.372
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.169
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.video.tt
#     </
# New feature weights:
#                feature      coef
# 0      part_of_day_day  0.566508
# 1  part_of_day_evening -3.205791
# 2  part_of_day_morning -3.249249
# 3         full_session  0.735207
# 4           year_month -0.492315
# 5          day_of_week -0.384524

# %% [markdown]
# We hit 0.95452 ROC_AUC public score with that. Wow! Maybe additional feature work will improve that.
#
# # Add number of sites feature

# %%
new_train_features = add_new_features(train_times, ['full_session', 'year_month', 'day_of_week', 'num_of_sites'],
                                      ['part_of_day'])
new_test_features = add_new_features(test_times, ['full_session', 'year_month', 'day_of_week', 'num_of_sites'], 
                                     ['part_of_day'])

X_train_sites_with_time = hstack([X_train_sites, new_train_features])
X_test_sites_with_time = hstack([X_test_sites, new_test_features])
# Train model with new features
X_train_sites_with_time.shape, X_test_sites_with_time.shape
# Out:
# ((253561, 50007), (82797, 50007))

# %% [markdown]
# # Train model with new features

# %%
new_features = list(new_train_features.columns)

cv_scores6 = train_and_predict(model=lr, X_train=X_train_sites_with_time, y_train=y_train, 
                               X_test=X_test_sites_with_time, site_feature_names=vectorizer.get_feature_names(),              
                               new_feature_names=new_features, cv=tss, submission_file_name='subm6.csv')
# Out:
# CV scores [0.84269621 0.80433987 0.9480185  0.96926425 0.91902517 0.95862632
#  0.93870808 0.95004992 0.9605795  0.96930392]
# CV mean: 0.9260611734347994, CV std: 0.05387139439334115
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.604
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.807
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.454
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.388
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.64%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.361
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.347
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         tru.am
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.214
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.149
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.23%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.049
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.930
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.827
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.792
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.743
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.716
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.708
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.538
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.468
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.44%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.425
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.radio-canada.ca
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.53%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.382
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.53%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.379
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.374
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.clermont-filmfest.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.193
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.video.tt
#     </
# New feature weights:
#                feature      coef
# 0      part_of_day_day  1.114105
# 1  part_of_day_evening -2.797853
# 2  part_of_day_morning -2.707488
# 3         full_session  1.222173
# 4           year_month -0.492322
# 5          day_of_week -0.384195
# 6         num_of_sites -0.254189

# %% [markdown]
# ROC_AUC score is 0.95418, slightly worse
#
# # Add Wednesday flag

# %%
train_times['day_of_week'] = pd.Categorical(train_times['day_of_week'])
test_times['day_of_week'] = pd.Categorical(test_times['day_of_week'])

new_train_features = add_new_features(train_times, ['full_session', 'year_month'], ['part_of_day', 'day_of_week'])
new_test_features = add_new_features(test_times, ['full_session', 'year_month'], ['part_of_day', 'day_of_week'])

cols_to_drop = [f'day_of_week_{i}' for i in range(0, 7) if i != 2]
new_train_features = new_train_features.drop(cols_to_drop, axis=1)
new_test_features = new_test_features.drop(cols_to_drop, axis=1)

X_train_sites_with_time = hstack([X_train_sites, new_train_features])
X_test_sites_with_time = hstack([X_test_sites, new_test_features])
# Train model with new features
X_train_sites_with_time.shape, X_test_sites_with_time.shape
# Out:
# ((253561, 50006), (82797, 50006))

# %%
new_features = list(new_train_features.columns)
lr = LogisticRegression(C=2.069, random_state=SEED, solver='liblinear')

cv_scores7 = train_and_predict(model=lr, X_train=X_train_sites_with_time, y_train=y_train, 
                               X_test=X_test_sites_with_time, site_feature_names=vectorizer.get_feature_names(),              
                               new_feature_names=new_features, cv=tss, submission_file_name='subm7.csv')
# Out:
# CV scores [0.90983054 0.85898195 0.95621547 0.98182016 0.92968001 0.96991708
#  0.94233071 0.953296   0.77013687 0.96153525]
# CV mean: 0.9233744038707463, CV std: 0.06101056087778373
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.004
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.906
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.623
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.48%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.569
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.428
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.299
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         tru.am
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.259
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.058
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.019
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.970
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.786
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.775
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         seriestreaming.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.772
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.710
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.video.tt
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.632
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.623
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.606
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.583
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.540
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.rhonealpesjob.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.63%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.500
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         reviewer.lavoixdunord.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.469
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.241
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.clermont-filmfest.com
#     </td>
# New feature weights:
#                feature      coef
# 0      part_of_day_day  0.490076
# 1  part_of_day_evening -3.412281
# 2  part_of_day_morning -3.307766
# 3        day_of_week_2 -2.820927
# 4         full_session  0.688419
# 5           year_month -0.339681

# %% [markdown]
# Got 0.94725 - bad decision
#
# # Drop part of day - day and year_month features

# %%
train_times['day_of_week'] = train_times['day_of_week'].astype(int)
test_times['day_of_week'] = test_times['day_of_week'].astype(int)

new_train_features = add_new_features(train_times, ['full_session', 'year_month', 'day_of_week'], ['part_of_day'])
new_test_features = add_new_features(test_times, ['full_session', 'year_month',  'day_of_week'], ['part_of_day'])

new_train_features = new_train_features.drop('part_of_day_day', axis=1)
new_test_features = new_test_features.drop('part_of_day_day', axis=1)

X_train_sites_with_time = hstack([X_train_sites, new_train_features])
X_test_sites_with_time = hstack([X_test_sites, new_test_features])
# Train model with new features
X_train_sites_with_time.shape, X_test_sites_with_time.shape
# Out:
# ((253561, 50005), (82797, 50005))

# %%
new_features = list(new_train_features.columns)

cv_scores8 = train_and_predict(model=lr, X_train=X_train_sites_with_time, y_train=y_train, 
                               X_test=X_test_sites_with_time, site_feature_names=vectorizer.get_feature_names(),              
                               new_feature_names=new_features, cv=tss, submission_file_name='subm8.csv')
# Out:
# CV scores [0.84825475 0.80462694 0.94791573 0.96788568 0.91965955 0.9586032
#  0.93390633 0.95028535 0.96052731 0.96952135]
# CV mean: 0.9261186182144824, CV std: 0.05277500572049672
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.612
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.812
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.446
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.395
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.358
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.348
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         tru.am
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.95%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.201
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.147
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.23%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.053
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.47%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.925
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.825
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.791
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.738
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.717
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.715
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.527
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.465
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.427
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.radio-canada.ca
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.378
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.375
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.375
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.clermont-filmfest.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.169
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.video.tt
#     </
# New feature weights:
#                feature      coef
# 0  part_of_day_evening -3.642849
# 1  part_of_day_morning -3.807230
# 2         full_session  0.774145
# 3           year_month -0.492318
# 4          day_of_week -0.384316

# %% [markdown]
# ROC_AUC is 0.95423. Let's try with sesion length
#
# # Add session length feature

# %%
new_train_features = add_new_features(train_times, ['session_length', 'year_month', 'day_of_week'],
                                      ['part_of_day'])
new_test_features = add_new_features(test_times, ['session_length', 'year_month', 'day_of_week'], 
                                     ['part_of_day'])

X_train_sites_with_time = hstack([X_train_sites, new_train_features])
X_test_sites_with_time = hstack([X_test_sites, new_test_features])
# Train model with new features
X_train_sites_with_time.shape, X_test_sites_with_time.shape
# Out:
# ((253561, 50006), (82797, 50006))

# %%
new_features = list(new_train_features.columns)
lr = LogisticRegression(C=2.069, random_state=SEED, solver='liblinear')

cv_scores9 = train_and_predict(model=lr, X_train=X_train_sites_with_time, y_train=y_train, 
                               X_test=X_test_sites_with_time, site_feature_names=vectorizer.get_feature_names(),              
                               new_feature_names=new_features, cv=tss, submission_file_name='subm9.csv')
# Out:
# CV scores [0.84221483 0.80718615 0.94826643 0.96774782 0.92050783 0.95946363
#  0.93463021 0.95085652 0.96134284 0.96932312]
# CV mean: 0.9261539380214467, CV std: 0.05323855492079396
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.603
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.774
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.52%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.425
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.355
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.335
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         tru.am
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.335
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.222
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.133
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.095
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.044
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.810
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.77%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.767
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.714
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.691
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.669
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.30%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.495
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.463
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.420
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.393
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.radio-canada.ca
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.357
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.clermont-filmfest.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.352
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.284
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.video.tt
#     </
# New feature weights:
#                feature      coef
# 0      part_of_day_day  0.746126
# 1  part_of_day_evening -3.067847
# 2  part_of_day_morning -3.071867
# 3       session_length -0.229705
# 4           year_month -0.492395
# 5          day_of_week -0.386447

# %% [markdown]
# Got 0.95486 ROC_AUC score. Nice! Now let's tune model parameters
